# %% [markdown]
# Report 4: Train model Linear Regression Basic
#
#
# Link Video hướng dẫn: https://youtu.be/U2885eNc3oc
#
# Nói lại 1 chút dataset
# Báo cáo chi tiết về Code: Basic Linear Regression  <code 1 cách rất cơ chúng ta để xem data thế nào> - code trong folder: https://drive.google.com/drive/folders/1ztFuR68LSzvMKKPUyUdEhgioX8eoJy_B
# Sáng mai nếu mà oke thì call mình giải thích thêm
# Hoặc tối mai nhưng phải tầm sau 19h hơn tí
# —-------
# Chi tiết em xem bên dưới nhé:
#
# Bộ dataset: Dataset: https://www.kaggle.com/competitions/playground-series-s4e5/data
# Mô tả bộ dataset 1 cuộc thi trên Kaggle - năm 2024.
#
#
# Dataset này cung cấp các yếu tố khác nhau ảnh hưởng đến xác suất lũ lụt, là biến mục tiêu cần dự đoán. Mỗi dòng đại diện cho một tập hợp điều kiện ở một khu vực cụ thể và mỗi cột là một yếu tố có thể góp phần làm tăng hoặc giảm nguy cơ lũ lụt. Dưới đây là mô tả các đặc trưng:
#
# 1. MonsoonIntensity (Cường độ gió mùa): Phản ánh mức độ mạnh yếu của mưa gió mùa trong khu vực.
# 2. TopographyDrainage (Địa hình thoát nước): Đo lường mức độ hiệu quả của địa hình trong việc thoát nước.
# 3. RiverManagement (Quản lý sông ngòi): Đánh giá chất lượng và hiệu quả của các biện pháp quản lý sông ngòi.
# 4. Deforestation (Phá rừng): Thể hiện mức độ mất cây xanh, với giá trị cao cho thấy mất mát cây lớn.
# 5. Urchúng taization (Đô thị hóa): Đo lường mức độ phát triển đô thị, có thể ảnh hưởng đến thoát nước tự nhiên và tăng nguy cơ lũ lụt.
# 6. ClimateChange (Biến đổi khí hậu): Thể hiện ảnh hưởng của biến đổi khí hậu đến các mô hình thời tiết địa phương.
# 7. DamsQuality (Chất lượng đập): Đánh giá tình trạng và hiệu quả của các đập nước trong việc kiểm soát dòng chảy.
# 8. Siltation (Bồi đắp phù sa): Đo lượng bồi đắp phù sa, có thể làm giảm dòng chảy và sức chứa nước của sông.
# 9. AgriculturalPractices (Thực hành nông nghiệp): Mô tả các biện pháp canh tác có thể ảnh hưởng đến giữ nước và đất.
# 10. Encroachments (Lấn chiếm): Đo lường mức độ lấn chiếm của con người trên các nguồn nước tự nhiên hoặc vùng bãi lũ.
# 11. IneffectiveDisasterPreparedness (Chuẩn bị ứng phó thiên tai không hiệu quả): Phản ánh mức độ sẵn sàng ứng phó với thảm họa.
# 12. DrainageSystems (Hệ thống thoát nước): Đánh giá chất lượng và hiệu quả của các hệ thống thoát nước nhân tạo.
# 13. CoastalVulnerability (Tính dễ tổn thương ven biển): Thể hiện mức độ dễ bị ngập lụt ven biển (nếu có).
# 14. Landslides (Sạt lở đất): Chỉ ra tần suất hoặc nguy cơ xảy ra sạt lở đất, có thể góp phần vào lũ lụt.
# 15. Watersheds (Lưu vực nước): Đo lường sức khỏe và sự ổn định của các lưu vực nước, giúp quản lý dòng chảy.
# 16. DeterioratingInfrastructure (Cơ sở hạ tầng xuống cấp): Phản ánh tình trạng cơ sở hạ tầng có thể ảnh hưởng đến khả năng chống lũ.
# 17. PopulationScore (Điểm dân số): Đại diện cho mật độ dân số, mật độ cao hơn có thể làm tăng tác động của lũ lụt.
# 18. WetlandLoss (Mất đất ngập nước): Chỉ mức độ mất đất ngập nước, có thể làm giảm khả năng giữ nước tự nhiên.
# 19. InadequatePlanning (Quy hoạch không đầy đủ): Đo lường mức độ quy hoạch và quản lý phát triển có thể giảm thiểu nguy cơ lũ.
# 20. PoliticalFactors (Yếu tố chính trị): Thể hiện các yếu tố chính trị hoặc quản lý ảnh hưởng đến quản lý lũ lụt.
#
# Biến mục tiêu:
# - FloodProbability (Xác suất lũ lụt): Biến liên tục chỉ ra xác suất xảy ra lũ lụt trong khu vực.
#
#
#
# Code
# code
#
# Sáng mai nếu mà oke thì call mình giải thích thêm
# Hoặc tối mai nhưng phải tầm sau 19h hơn tí
#
# oke.

# %% [markdown]
# Report 5: Linear Regression với Lasso Regression và Ridge Regression
#
#
#
#  Lasso và Ridge Regression - 2 phương pháp cải thiện Linear Regression
#
# Cách giải thích đơn giản
#
#  1. Lasso Regression:
# - Định nghĩa đơn giản:
#   - Lasso Regression (Least Absolute Shrinkage and Selection Operator) là một phương pháp mở rộng của Linear Regression, giúp giảm thiểu việc mô hình bị quá khớp (overfitting).
#   - Thay vì chỉ vẽ một đường thẳng qua dữ liệu, Lasso sẽ tìm cách loại bỏ hoàn toàn các yếu tố ít quan trọng chúng tag cách đưa hệ số của chúng về 0.
#
# - Ví dụ đơn giản:
#   - Giả sử chúng ta đang làm bài tập dự đoán điểm số, nhưng có quá nhiều yếu tố liên quan (thời gian học, chất lượng giáo viên, số lượng bài tập,...).
#   - Lasso sẽ tự động loại bỏ những yếu tố ít quan trọng (ví dụ, "số lượng bài tập" có thể không ảnh hưởng đáng kể) để chỉ tập trung vào những yếu tố quan trọng nhất.
#
# - Cách hoạt động:
#   - Lasso thêm một hình phạt (penalty) vào phương trình dự đoán, và hình phạt này phụ thuộc vào tổng giá trị tuyệt đối của các hệ số.
#
# ---
#
#  2. Ridge Regression:
# - Định nghĩa đơn giản:
#   - Ridge Regression là một phương pháp khác để giảm overfitting, tương tự như Lasso, nhưng thay vì loại bỏ hoàn toàn các yếu tố ít quan trọng, nó đẩy các hệ số này gần về 0 mà không đưa về 0 hẳn.
#
# - Ví dụ đơn giản:
#   - Nếu chúng ta dự đoán điểm số với nhiều yếu tố, Ridge sẽ không loại bỏ yếu tố nào hoàn toàn. Thay vào đó, nó giảm mức độ ảnh hưởng của những yếu tố ít quan trọng, để mô hình không phụ thuộc quá nhiều vào chúng.
#
# - Cách hoạt động:
#   - Ridge cũng thêm một hình phạt, nhưng hình phạt này phụ thuộc vào bình phương của các hệ số (thay vì giá trị tuyệt đối như Lasso).
#
# ---
#
#  So sánh Lasso và Ridge:
# | Thuật toán | Loại bỏ yếu tố ít quan trọng | Tối ưu cho số lượng biến | Mức độ giảm overfitting |
# |----------------|-----------------------------------|------------------------------|-----------------------------|
# | Lasso      | Hoàn toàn đưa hệ số về 0         | Tốt khi có nhiều biến dư thừa| Mạnh hơn (có thể loại bỏ biến)|
# | Ridge      | Đưa hệ số về gần 0               | Tốt khi tất cả biến đều liên quan| Nhẹ nhàng hơn (giữ tất cả biến)|
#
# ---
#
#  Ứng dụng vào dự đoán xác suất lũ lụt:
# - Lasso:
#   - Nếu có nhiều yếu tố dư thừa (ít ảnh hưởng, ví dụ "chất lượng đất"), Lasso sẽ loại bỏ hoàn toàn những yếu tố này để tập trung vào những yếu tố quan trọng như "lượng mưa" hoặc "khả năng thoát nước".
# - Ridge:
#   - Giữ lại tất cả các yếu tố nhưng giảm bớt mức độ ảnh hưởng của các yếu tố ít quan trọng để đảm bảo mô hình không quá phụ thuộc vào chúng.
#
#
#
# Cách implement 2 thuật toán vào code: https://drive.google.com/file/d/1qeuH47yRn74ABpO4exTQ7MeSDervWOKH/view?usp=sharing

# %% [markdown]
# Report 5: Chuẩn hóa dữ liệu và KNN
#
# chuẩn hóa dữ liệu
#
#  1. Chuẩn hóa là gì?
# Chuẩn hóa là kỹ thuật chuyển đổi các giá trị của dữ liệu về cùng một phạm vi, thường là từ 0 đến 1 hoặc biến đổi để có giá trị trung bình là 0 và độ lệch chuẩn là 1.
#
#  2. Giải thích chuẩn hóa một cách dễ hiểu (Ví dụ về bài toán giá nhà)
#
# Hãy tưởng tượng chúng ta đang xây dựng một mô hình để dự đoán giá nhà, với các yếu tố sau:
# - Diện tích nhà: Tính chúng tag mét vuông, thường có giá trị từ 50 đến 500 m².
# - Khoảng cách tới trung tâm thành phố: Tính chúng tag kilômét, thường có giá trị từ 1 đến 50 km.
# - Số phòng ngủ: Là số nguyên, thường từ 1 đến 5.
#
# ---
#
#  Tại sao cần chuẩn hóa?
#
#  Thang đo không đồng nhất:
# - Diện tích nhà có giá trị từ 50 đến 500, quá lớn so với các yếu tố khác.
# - Khoảng cách tới trung tâm chỉ từ 1 đến 50.
# - Số phòng ngủ từ 1 đến 5.
#
# Khi mô hình học, nó sẽ coi diện tích nhà là yếu tố quan trọng nhất chỉ vì giá trị của nó lớn hơn, dù trong thực tế, khoảng cách tới trung tâm có thể ảnh hưởng lớn hơn đến giá nhà.
#
#  Giải pháp: Chuẩn hóa dữ liệu
# Quy đổi tất cả các yếu tố về cùng một phạm vi (0 đến 1). Ví dụ:
# - Diện tích nhà: Nếu là 250 m² (giữa khoảng 50-500), sẽ trở thành 0.5.
# - Khoảng cách tới trung tâm: Nếu là 25 km (giữa khoảng 1-50), sẽ trở thành 0.5.
# - Số phòng ngủ: Nếu là 3 (giữa khoảng 1-5), sẽ trở thành 0.5.
#
# Khi đó, mô hình sẽ đánh giá các yếu tố dựa trên mối quan hệ thực sự thay vì kích thước giá trị của chúng.
#
# ---
#
#  3. Ứng dụng chuẩn hóa vào bài toán dự đoán bão lũ
#
# Trong bài toán dự đoán xác suất lũ lụt, chúng ta cũng có nhiều yếu tố với thang đo khác nhau. Ví dụ:
# - Lượng mưa: Có giá trị lớn, từ 0 đến vài ngàn mm.
# - Chất lượng đê điều: Là số điểm từ 0 đến 10.
# - Mật độ dân số: Có thể dao động từ vài chục đến hàng nghìn người/km².
#
#  Vấn đề nếu không chuẩn hóa:
# - Lượng mưa có giá trị lớn sẽ được mô hình coi là yếu tố quan trọng nhất, ngay cả khi nó không phải yếu tố quyết định duy nhất.
# - Các yếu tố như chất lượng đê điều, dù quan trọng, có giá trị nhỏ hơn, sẽ bị bỏ qua.
#
#  Lợi ích khi chuẩn hóa:
# - Tất cả các yếu tố đều được đánh giá công chúng tag.
# - Mô hình Linear Regression hoặc các biến thể như Ridge, Lasso sẽ chính xác hơn khi tính toán hệ số (coefficients) cho từng yếu tố.
# - Giảm nguy cơ mô hình "hiểu nhầm" về tầm quan trọng của các biến.
#
# ---
#
#  Kết luận:
# Chuẩn hóa không chỉ giúp mô hình hoạt động chính xác hơn mà còn đảm bảo rằng các yếu tố trong bài toán được đánh giá công chúng tag. Trong bài toán dự đoán lũ lụt, việc chuẩn hóa các yếu tố như lượng mưa, chất lượng đê điều, và mật độ dân số sẽ giúp mô hình phản ánh đúng thực tế hơn và đưa ra dự đoán đáng tin cậy.

# %% [markdown]
# -+Report 6: Chuẩn hóa dữ liệu và KNN
#
# KNN
#
# - Thuật toán K-Nearest Neighbors (KNN) (K láng giềng gần nhất)
#   - Định nghĩa đơn giản:
#     - KNN là thuật toán dựa vào các ví dụ "gần nhất" trong dữ liệu đã có.
#     - Khi cần dự đoán cho một trường hợp mới, KNN sẽ tìm k trường hợp trước đó có các yếu tố tương tự và xem kết quả là gì.
#     - Dựa trên kết quả này, KNN đưa ra dự đoán cho trường hợp mới.
#   - Ví dụ đơn giản:
#     - Giả sử một học sinh muốn dự đoán điểm số của mình trong lần thi sắp tới.
#     - Em ấy có thể tìm điểm số của những lần thi gần nhất mà điều kiện học tập của em ấy tương tự (thời gian học, số lần ôn tập, vv).
#     - Dựa vào các điểm số trước đó, em ấy có thể ước lượng điểm thi sắp tới của mình.
#   - Ứng dụng vào dự đoán xác suất lũ lụt:
#     - Trong bài toán dự đoán lũ, KNN sẽ xem xét những ngày trong quá khứ có điều kiện thời tiết, cường độ mưa, và các yếu tố tương tự.
#     - Ví dụ, nếu có một ngày nào đó có lượng mưa và độ ẩm giống với những ngày trước đó đã từng xảy ra lũ, KNN sẽ dự đoán rằng ngày mới này cũng có nguy cơ cao xảy ra lũ lụt.
#
#
# Triển khai trong code: https://drive.google.com/file/d/1gn4Az1MW6HnPaoZeJyNVokdXcxwIw8fW/view?usp=sharing

# %% [markdown]
# W7_Hyperparameter Tuning
#
#
# - Mục tiêu của bài toán là gì?
# - Hyper giúp gì cho mục tiêu đó?
# - Cách nó hoạt động như nào?
# 1. Mục tiêu của bài toán
# Bài toán: Dự đoán xác suất lũ lụt (Flood Probability Prediction)
# Mục tiêu chính:
# Dự đoán xác suất xảy ra lũ lụt tại một khu vực dựa trên các dữ liệu đầu vào như lượng mưa, độ ẩm, đặc điểm địa hình, lưu vực sông, v.v.
# Tăng độ chính xác dự đoán, đảm bảo mô hình không chỉ hoạt động tốt trên dữ liệu huấn luyện mà còn hiệu quả trên dữ liệu thực tế.
# Giảm thiểu sai số trong dự đoán bằng cách tối ưu hóa mô hình.
# Cung cấp thông tin hỗ trợ ra quyết định: Dự đoán chính xác hơn giúp cơ quan chức năng triển khai các biện pháp phòng tránh hoặc giảm thiểu tác động của lũ lụt.
#
# 2. Hyperparameter Tuning giúp gì cho mục tiêu đó?
# Hyperparameter Tuning đóng vai trò:
# Cải thiện độ chính xác của mô hình:
# Tìm các tham số tốt nhất (hyperparameters) giúp mô hình dự đoán chính xác hơn.
# Ví dụ: Nếu tham số alpha không được tối ưu, mô hình có thể overfit (nhớ quá kỹ dữ liệu cũ) hoặc underfit (không đủ khả năng nắm bắt xu hướng).
# Tăng khả năng tổng quát hóa:
# Mô hình không chỉ hoạt động tốt trên dữ liệu huấn luyện mà còn có khả năng dự đoán chính xác trên dữ liệu thực tế (tập kiểm tra).
# Giảm hiện tượng overfitting và underfitting:
# Ví dụ: alpha điều chỉnh mức độ "hình phạt" cho các trọng số lớn. Nếu không tối ưu, mô hình có thể không cân bằng giữa việc học từ dữ liệu huấn luyện và áp dụng vào dữ liệu mới.
# Tiết kiệm thời gian thử nghiệm thủ công:
# Thay vì tự thử từng tham số, Hyperparameter Tuning tự động hóa quá trình này để tìm ra tham số tối ưu nhất.
# Nâng cao giá trị dự báo:
# Khi mô hình đạt độ chính xác cao hơn, nó cung cấp các dự báo đáng tin cậy hơn cho việc ra quyết định phòng tránh lũ lụt.
#
# 3. Hyperparameter Tuning hoạt động như thế nào?
# Bản chất của Hyperparameter Tuning:
# Là quá trình tự động thử nghiệm nhiều tổ hợp tham số khác nhau để tìm ra tổ hợp tốt nhất.
# Tham số mô hình (hyperparameters) là các "nút điều chỉnh" ảnh hưởng trực tiếp đến cách mô hình học từ dữ liệu và đưa ra dự đoán.
#
# Quy trình hoạt động:
# Xác định tham số cần tối ưu:
# Các tham số trong Ridge Regression:
# alpha: Độ mạnh của regularization (giảm hiện tượng overfitting).
# solver: Phương pháp toán học để giải bài toán tối ưu.
# max_iter: Số lần lặp tối đa để thuật toán hội tụ.
# tol: Ngưỡng sai số tối thiểu để dừng lặp.
# Lựa chọn phương pháp Hyperparameter Tuning:
# Grid Search:
# Thử tất cả các tổ hợp tham số trong một phạm vi xác định.
# Hoạt động: Lần lượt kết hợp các giá trị của tham số alpha, solver, max_iter, v.v., tính toán hiệu quả của mỗi tổ hợp và chọn tổ hợp tốt nhất.
# Ưu điểm: Tìm được tham số tốt nhất một cách chắc chắn.
# Nhược điểm: Tốn thời gian nếu số lượng tham số lớn.
# Randomized Search:
# Thử ngẫu nhiên một số tổ hợp tham số trong phạm vi xác định.
# Hoạt động: Lấy mẫu ngẫu nhiên một số tổ hợp, đánh giá hiệu quả, và chọn tổ hợp tốt nhất.
# Ưu điểm: Nhanh hơn Grid Search.
# Nhược điểm: Có thể bỏ lỡ tham số tối ưu nhất.
# Chạy thử mô hình với từng tổ hợp tham số:
# Sử dụng dữ liệu huấn luyện (training data) để huấn luyện mô hình với từng tổ hợp tham số.
# Tính toán hiệu quả dự đoán trên dữ liệu kiểm tra (validation data).
# Chọn tổ hợp tham số tốt nhất:
# Dựa trên kết quả từ bước 3, chọn tổ hợp tham số tối ưu nhất theo các chỉ số đánh giá như:
# R² Score: Mức độ mô hình giải thích được biến động của dữ liệu.
# MSE/MAE: Sai số trung bình.
# RMSE/MAPE: Sai số trung bình dưới dạng phần trăm.
# Áp dụng tham số tối ưu vào mô hình cuối cùng:
# Huấn luyện mô hình với tập hợp tham số tối ưu trên toàn bộ dữ liệu (training + validation).
# Đánh giá lần cuối trên tập kiểm tra (test set).
# ======================================================================
#
# Các tham số (Hyperparameters) của 1 model
# Hyperparameter Tuning (tối ưu tham số) là gì và tại sao cần Hyperparameter Tuning?
# Grid Search (tìm kiếm theo lưới) và Randomized Search (tìm kiếm ngẫu nhiên) trong việc lựa chọn tham số tốt nhất
# —-----------------------------
# Hyperparameter Tuning là cách thử nhiều lần với lượng muối khác nhau để tìm công thức ngon nhất.
# - Tham số là nút điều chỉnh để mô hình hoạt động tốt.
# - Hyperparameter Tuning giúp tự động tìm nút điều chỉnh tối ưu.
# - Grid Search: Thử tất cả -> Chính xác nhưng lâu.
# - Randomized Search: Thử ngẫu nhiên -> Nhanh hơn, nhưng không chắc chắn.
#
# Code: https://drive.google.com/file/d/1xHNFa38JbUvjG5zT-9o6hoqn4501qBjx/view?usp=sharing
#
#
#  1. Các tham số (Hyperparameters) của 1 model
#
# Tham số là các nút điều chỉnh của mô hình để giúp nó hoạt động tốt hơn.
# Ví dụ:
# alpha: Điều chỉnh độ mạnh của "hình phạt" nếu mô hình cố làm việc quá mức.
# solver: Chọn cách giải toán để tìm câu trả lời.
# fit_intercept: Có thêm số bắt đầu (intercept) vào công thức hay không.
# tol: Ngưỡng dừng lại nếu thay đổi quá nhỏ.
# max_iter: Số lần thử nghiệm tối đa trước khi dừng.
# Tưởng tượng: chúng ta đang lái xe, "alpha" như tốc độ, "solver" là cách chọn đường đi, và "max_iter" là số lần chúng ta sẵn sàng lặp lại để tìm đường tốt nhất.
#
#
# ---
#
#  2. Hyperparameter Tuning (tối ưu tham số) là gì và tại sao cần Hyperparameter Tuning?
#
# Đơn giản: Là cách chọn "nút điều chỉnh" (tham số) tốt nhất để mô hình hoạt động hiệu quả nhất.
# Ví dụ dễ hiểu:
# chúng ta nấu mì. Nếu cho nhiều muối, mì mặn. Nếu ít muối, mì nhạt. Hyperparameter Tuning là cách thử nhiều lần với lượng muối khác nhau để tìm công thức ngon nhất.
#
#
# ---
#
#  3. Grid Search (tìm kiếm theo lưới) và Randomized Search (tìm kiếm ngẫu nhiên) trong việc lựa chọn tham số tốt nhất
#
# Grid Search:
# Thử tất cả các kết hợp tham số chúng ta đưa ra.
# Ví dụ:
# chúng ta thử từng mức muối (ít, vừa, nhiều) với từng loại gia vị (ngọt, cay). Tổng cộng chúng ta thử 6 cách nấu ăn.
# Ưu điểm: Chắc chắn tìm ra cách nấu ngon nhất.
# Nhược điểm: Mất nhiều thời gian nếu có quá nhiều tùy chọn.
# Randomized Search:
# Thử ngẫu nhiên một vài cách thay vì tất cả.
# Ví dụ:
# chúng ta thử ngẫu nhiên 3 trong số 6 cách nấu.
# Ưu điểm: Nhanh hơn, tiết kiệm thời gian.
# Nhược điểm: Có thể bỏ lỡ cách nấu ngon nhất.
#
#
# ---
#
# Tóm lại
# Tham số là nút điều chỉnh để mô hình hoạt động tốt.
# Hyperparameter Tuning giúp tự động tìm nút điều chỉnh tối ưu.
# Grid Search: Thử tất cả -> Chính xác nhưng lâu.
# Randomized Search: Thử ngẫu nhiên -> Nhanh hơn, nhưng không chắc chắn.
#
#
#
#
# ===============================================================
#
#  Ứng Dụng Trong Bài Toán Hiện Tại
#
# Trong bài toán dự đoán xác suất lũ lụt (FloodProbability), chúng ta cần tối ưu hóa các tham số của mô hình Ridge Regression để đạt được dự đoán chính xác nhất. Các bước ứng dụng Grid Search và Randomized Search trong bài toán này bao gồm:
#
# ---
#
#  1. Xác định các tham số cần tối ưu
# Trong Ridge Regression, chúng ta có các tham số cần tối ưu hóa:
# alpha: Điều chỉnh độ mạnh của regularization (giảm overfitting).
# solver: Chọn phương pháp toán học để tìm hệ số (vd: auto, svd, lsqr).
# fit_intercept: Quyết định có thêm hệ số chặn (intercept) vào công thức hay không.
# max_iter: Số lần lặp tối đa của thuật toán.
# tol: Ngưỡng sai số nhỏ nhất để thuật toán dừng.
#
#
# ```
# param_Ridge = {
#     'alpha': [0.001, 0.01, 0.1, 1, 10, 100], # L2 regularization strength
#     'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'], # pp giải quyết optimal values
#     'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag'],  # sparse_cg, saga not support
#     'fit_intercept': [True, False], # model có dùng hệ số chặn không.
#     'copy_X': [True, False],
#     'max_iter': [None, 1000, 5000],
#     'tol': [0.001, 0.0001, 0.00001], # độ biến thiên tối thiểu cho phép tiếp tục huấn luyện.
#     'positive': [True, False],
#     'random_state': [42] # or any other integer value
# }
# ```
#
# ---
# 2. Sử dụng Randomized Search để tối ưu tham số
# Randomized Search phù hợp với bài toán hiện tại vì số lượng tham số lớn và cần tiết kiệm thời gian tính toán.
# Chúng ta thử ngẫu nhiên một số kết hợp của các giá trị alpha, solver, fit_intercept, v.v., để tìm ra tham số tốt nhất.
#
#
#
# ---
#
#  3. Đánh giá kết quả với tham số tối ưu
# Sau khi tìm được tham số tốt nhất, sử dụng mô hình với các tham số này để dự đoán và đánh giá hiệu quả chúng tag các chỉ số:
# R² Score: Độ giải thích của mô hình.
# MSE (Mean Squared Error): Sai số trung bình bình phương.
# RMSE (Root Mean Squared Error): Căn bậc hai của MSE.
# MAE (Mean Absolute Error): Sai số trung bình tuyệt đối.
# MAPE (Mean Absolute Percentage Error): Sai số phần trăm trung bình tuyệt đối.
# ---
#
# 4. Ý nghĩa của ứng dụng
# Việc tối ưu tham số giúp mô hình Ridge Regression đạt hiệu quả cao nhất.
# Giảm hiện tượng overfitting (mô hình hoạt động tốt trên tập train nhưng kém trên tập test).
# Cải thiện độ chính xác khi dự đoán xác suất lũ lụt, giúp chúng ta hiểu được các yếu tố ảnh hưởng mạnh nhất đến lũ lụt.
